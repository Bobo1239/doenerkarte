# %%
import requests
import pandas as pd
import folium

# %%
api_key = 'AIzaSyAn_1vHU9EfL2QxQBVCt0O8ftzdZieGdic'
location = '48.192091, 11.616458'  # Replace with the latitude and longitude of your desired location
radius = 2500  # Radius in meters, adjust as needed<

# %%
radius_2500 = 2500
# doener_data_2500 = pd.DataFrame(columns=['name', 'address', 'lat', 'lon'])

url = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location}&radius={radius}&types=restaurant&keyword=döner&key={api_key}'

response = requests.get(url)
data_2500 = response.json()

# doener_data = pd.concat([doener_data, pd.DataFrame(data['candidates'])], ignore_index=True, sort=False)
doener_data_2500_list = []
for idx, place in enumerate(data_2500['results']):
    doener_data_2500_list.append({
        'name': place['name'],
        'address': place['vicinity'],
        'lat': float(place['geometry']['location']['lat']),
        'lon': float(place['geometry']['location']['lng'])
    })

doener_data_2500 = pd.DataFrame(doener_data_2500_list)                        
print(doener_data_2500)
# Out:
#                                            name  \
# 0                     Sindbad Kebap & Grillhaus
# 1                                  Orient Döner
# 2                                  LOKO'S DÖNER
# 3               Torros Kebap Torros grill house
# 4                           Uyghur burger kebab
# 5                                    DönerTreff
# 6                              Mamas Kebap Haus
# 7                                   Turka Kebap
# 8                                     Ora Kebap
# 9                       Vita Pizza Burger Döner
# 10               Estare Restaurant - Cafe - Bar
# 11                     Torros doner grill house
# 12                Hans Kebab am Schwabinger Tor
# 13                      Vita Pizza Burger Döner
# 14                       TÜRKITCH Köfte & Kebap
# 15  Kerri Imbiss Döner Kebap Cevapcici und mehr
# 16                            Pascha Restaurant
# 17                 OLIVA Food Münchner Freiheit
# ...

# %%
radius_3000 = 3000
location_3000 = "48.204325, 11.563385"
# doener_data_2500 = pd.DataFrame(columns=['name', 'address', 'lat', 'lon'])

url = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location_3000}&radius={radius}&types=restaurant&keyword=döner&key={api_key}'

response = requests.get(url)
data_3000 = response.json()

# doener_data = pd.concat([doener_data, pd.DataFrame(data['candidates'])], ignore_index=True, sort=False)
doener_data_3000_list = []
for idx, place in enumerate(data_3000['results']):
    doener_data_3000_list.append({
        'name': place['name'],
        'address': place['vicinity'],
        'lat': float(place['geometry']['location']['lat']),
        'lon': float(place['geometry']['location']['lng']),
        'rating': place['rating'],
        'place_id': place['place_id']
    })

doener_data_3000 = pd.DataFrame(doener_data_3000_list)                        
print(doener_data_3000)
# Out:
#                                            name  \
# 0                                  Orient Döner
# 1                                  LOKO'S DÖNER
# 2                           Uyghur burger kebab
# 3                                    DönerTreff
# 4                                        KEB UP
# 5                Estare Restaurant - Cafe - Bar
# 6                                  Loko's Kebab
# 7                 Hans Kebab am Schwabinger Tor
# 8                                     Ora Kebap
# 9                           Moosacher Imbiss II
# 10  Kerri Imbiss Döner Kebap Cevapcici und mehr
# 11                            Pascha Restaurant
# 12                 OLIVA Food Münchner Freiheit
# 13                       TÜRKITCH Köfte & Kebap
# 14                                  Döner kebab
# 15                EssPoint Pide & Grill München
# 16                                   Döner King
# 17                        Kebap | Pide | Burger
# ...

# %%
import json
print(data_2500)
print("--------------------------------------------------------------------------------------------------------------------------------")
print(data_3000)
json_responses = [data_2500, data_3000]
# Step 2: Combine JSON Responses into One Dictionary
merged_dict = {}
for response in json_responses:
    merged_dict.update(response)

# Step 3: Write the Merged Dictionary to a JSON File
output_file_path = 'merged_output.json'
with open(output_file_path, 'w') as json_file:
    json.dump(merged_dict, json_file, indent=2)
# Out:
# {'html_attributions': [], 'next_page_token': 'AcJnMuF61uy900BZfo1K7T1-8SNJTW90gcu4aIF9fR6Q8QWEsC4PlL5oY4wvSzZNjnHZPMFPidba55nROzXKMdQo_f4V8BX1EFsarnjKKc_-rqcL9RBu48kBXtVeaRdzuS2WbmEOE5nEZYXcOaPAhCCTfrxYRUu40RYICDsBzbjhVBJi5CYo2_MsEUlyb7sT7j0qCyiTWj6aPxZMQETDMrXMADeXMQCmRtM0U2MYREqh17ehfPiAaWXRc2rogQNJ013aZMjyDHgyd7-CFwTku6DWKvfGSYX9_Y0hDmZn_A-giSKrc4iIvUUWE2OYoADMa6xV-vaAc4UUwiVMjM9cqO8ZCY8BK-ag2BB7xB_8siay1Fm39ssW34iWBbWl-oymmsGCGwTLpCf_c1WsWhmQxnddkAfRx6fbxNDR8mc-seuinuk1p8eUAE_4ySJxaNBOjRXLTKPlviE', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.1508966, 'lng': 11.5646573}, 'viewport': {'northeast': {'lat': 48.15228347989272, 'lng': 11.56603027989272}, 'southwest': {'lat': 48.14958382010727, 'lng': 11.56333062010728}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'icon_background_color': '#FF9E67', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet', 'name': 
# ...

# %%
import shutil
from IPython.display import Image, display

max_width = 5000
photo_reference = "AcJnMuFRRFrmRoq4pEFyJRvRuQjIQoBwgPfd5zBcXGSEHUK_w7iR11ihKlaAF6GF1vwuSxC01pHUOQsVS3KRsnK9QfGQXo1ek5S_Kg_BWbbADrbgo8QAJnVKHFhXRqqO_BHKsvADgl9xvzzgfp6Jln61sXl3c9Hy1es_Rgam6v7UreDUyoCD"
# url = f"https://maps.googleapis.com/maps/api/place/photo?maxwidth={max_width}&photo_reference={photo_reference}&key={api_key}"
maps_url = f"https://www.google.com/maps/place/?q=place_id:{place_id}"

response_photo = requests.get(url, stream=True)

# Check if the request was successful (status code 200)
if response_photo.status_code == 200:
    # Save the photo locally
    with open("photo.jpg", "wb") as f:
        shutil.copyfileobj(response_photo.raw, f)
    
    # Display the photo
    display(Image(filename="photo.jpg"))
else:
    print(f"Error: Unable to fetch the photo. Status code: {response_photo.status_code}")

# %%
# merged_df = pd.merge(doener_data_2500, doener_data_3000, on='address', how='outer', indicator=True)

# # Filter rows based on the indicator column
# only_in_2500 = merged_df[merged_df['_merge'] == 'left_only']
# only_in_3000 = merged_df[merged_df['_merge'] == 'right_only']
# in_both = merged_df[merged_df['_merge'] == 'both']
# print("only in 2500")
# print(only_in_2500)
# print("only in 3000")
# print(only_in_3000)
# Out:
# only in 2500
#                                          name_x  \
# 3   Kerri Imbiss Döner Kebap Cevapcici und mehr
# 4                Estare Restaurant - Cafe - Bar
# 5                                   Della Terra
# 6                             Pascha Restaurant
# 7                     Gourmet Ecke Unterföhring
# 8                                   Ela2 Bistro
# 9                         Ariana Kebap & Burger
# 11                                      Drah Di
# 12                           Antalya Restaurant
# 15                          Freimanner Feinkost
# 16                              Imbiss grillbar
#
#                              address      lat_x      lon_x name_y  lat_y  \
# 3        Heidemannstraße 37, München  48.201634  11.591232    NaN    NaN
# 4           Echinger Str. 1, München  48.177390  11.601276    NaN    NaN
# 5   Margot-Kalinke-Straße 4, München  48.194144  11.597095    NaN    NaN
# 6       Ingolstädter Str. 1, München  48.184730  11.584290    NaN    NaN
# ...

# %%
radius = 5000
# doener_data_5000 = pd.DataFrame(columns=['name', 'address', 'lat', 'lon'])

url = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location}&radius={radius}&types=restaurant&keyword=döner&key={api_key}'

response = requests.get(url)
data = response.json()

# doener_data = pd.concat([doener_data, pd.DataFrame(data['candidates'])], ignore_index=True, sort=False)
doener_data_5000_list = []
for idx, place in enumerate(data['results']):
    doener_data_5000_list.append({
        'name': place['name'],
        'address': place['vicinity'],
        'lat': float(place['geometry']['location']['lat']),
        'lon': float(place['geometry']['location']['lng'])
    })

doener_data_5000 = pd.DataFrame(doener_data_5000_list)                        
print(doener_data_5000)
# Out:
#                                name                          address  \
# 0                     Fresh & Spicy   Maria-Probst-Straße 6, München
# 1                              pera     Helene-Mayer-Ring 6, München
# 2                  VIP Döner Imbiss     Riesenfeldstraße 77, München
# 3         Sindbad Kebap & Grillhaus      Theresienstraße 59, München
# 4                      Orient Döner  Hohenzollernstraße 103, München
# 5                      LOKO'S DÖNER  Schleißheimer Str. 506, München
# 6                      Family Döner      Kulturheimstraße 8, München
# 7                 Antep Kebap Döner        Belgradstraße 78, München
# 8                       Turka Kebap        Amalienstraße 49, München
# 9                    Habib’s Imbiss      Dachauer Str. 100a, München
# 10                       DönerTreff  Lerchenauer Str. 65-67, München
# 11                Alis Gemüse Döner   Alfred-Arndt-Straße 1, München
# 12                 Springtime Döner       Dachauer Str. 151, München
# ...

# %%
locaaa = [12.345, 23.456]
print(f"{locaaa[0]}, {locaaa[1]}")
# Out:
# 12.345, 23.456

# %%
doener_data = pd.concat([doener_data_2500, doener_data_5000], ignore_index=True).drop_duplicates(subset='address')

# %%
print(doener_data)
# Out:
#                                            name  \
# 0                                 Fresh & Spicy
# 1                             Alis Gemüse Döner
# 2                 Hans Kebab am Schwabinger Tor
# 3   Kerri Imbiss Döner Kebap Cevapcici und mehr
# 4                Estare Restaurant - Cafe - Bar
# 5                                   Della Terra
# 6                             Pascha Restaurant
# 7                     Gourmet Ecke Unterföhring
# 8                                   Ela2 Bistro
# 9                                  Family Döner
# 10                                      Drah Di
# 11                           Antalya Restaurant
# 12                      Vita Pizza Burger Döner
# 13                              GRILLstation JK
# 14                          Freimanner Feinkost
# 16                              Imbiss grillbar
# 18                                         pera
# 19                             VIP Döner Imbiss
# ...

# %%
map_center = [float(string) for string in location.split(', ')]
mymap = folium.Map(location=map_center, zoom_start=12)

# Add markers for each location
for place in doener_data_5000.iterrows():
    # print(place[1]['lat'])
    folium.Marker(
        location=[place[1]['lat'], place[1]['lon']],
        popup=place[1]['name'],
        color='blue'
    ).add_to(mymap)

folium.Circle(
    location=map_center,
    radius=5000,
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=0.3,
).add_to(mymap)

for place in doener_data_2500.iterrows():
    # print(place)
    folium.Marker(
        location=[place[1]['lat'], place[1]['lon']],
        popup=place[1]['name'],
        icon=folium.Icon(color='green',icon_color='#008000')
    ).add_to(mymap)
    
folium.Circle(
    location=map_center,
    radius=2500,
    color='green',
    fill=True,
    fill_color='green',
    fill_opacity=0.3,
).add_to(mymap)
# Save the map as an HTML file or display it
mymap  # Save the map as an HTML file
# Out:
# (0, name                        Fresh & Spicy
# address    Maria-Probst-Straße 6, München
# lat                             48.192272
# lon                             11.587396
# Name: 0, dtype: object)
# (1, name                    Alis Gemüse Döner
# address    Alfred-Arndt-Straße 1, München
# lat                             48.182763
# lon                             11.594248
# Name: 1, dtype: object)
# (2, name       Hans Kebab am Schwabinger Tor
# address       Leopoldstraße 182, München
# lat                            48.173205
# lon                            11.586192
# Name: 2, dtype: object)
# (3, name       Kerri Imbiss Döner Kebap Cevapcici und mehr
# address                    Heidemannstraße 37, München
# lat                                          48.201634
# lon                                          11.591232
# Name: 3, dtype: object)
# (4, name       Estare Restaurant - Cafe - Bar
# address          Echinger Str. 1, München
# ...

# %%
import numpy as np

def m_to_lon(m, reference_lat):
    # Earth radius at the equator (mean radius)
    earth_radius_m = 6371000

    # Calculate the circumference of the Earth at the given latitude
    earth_circumference_m_at_reference_latitude = 2 * np.pi * earth_radius_m * np.cos(reference_lat*np.pi/180)

    lon = (m / earth_circumference_m_at_reference_latitude)*360
    return lon

def m_to_lat(m):
    # lat constant at every point
    lat = m / 111177
    return lat

def lat_lon_grid(center, radius, width, height):
    # assert(width < 100000), f"width = {width}m is too large!"
    assert(height < 100000), f"height = {height}m is too large!"
    d = 2*radius
    # number of grid points in lon/width direction
    a = int(np.round(width/d))
    # number of grid points in lat/height direction
    b = int(np.round(height/d))
    r_adjusted = np.max([(width/a), (height/b)])/2

    lon_min = center[1] - m_to_lon(width/2, center[0])
    lon_max = center[1] + m_to_lon(width/2, center[0])
    lat_min = center[0] - m_to_lat(height/2)
    lat_max = center[0] + m_to_lat(height/2)
    # Generate a uniform grid in lon and lat dimensions with a, b grid points in each dimension
    lon_values = np.linspace(lon_min, lon_max, a)  # Adjust the range based on your requirements
    lat_values = np.linspace(lat_min, lat_max, b)  # Adjust the range based on your requirements
    
    # Create a 2D grid using meshgrid
    lat_grid, lon_grid = np.meshgrid(lat_values, lon_values)

    lat_lon_grid = np.column_stack((lat_grid.flatten(), lon_grid.flatten()))
    
    return lat_lon_grid, r_adjusted

# %%
munich="48.137174, 11.577493"
map_center = [float(string) for string in munich.split(', ')]
lat_lon_grid, r_adjusted = lat_lon_grid(map_center, 1500, 30000, 25000)
print(lat_lon_grid.shape[0])

mymap2 = folium.Map(location=map_center, zoom_start=11)

# Add markers for each location
for place in lat_lon_grid:
    # print(place[1]['lat'])
    folium.Marker(
        location=[place[0], place[1]],
        color='blue'
    ).add_to(mymap2)

mymap2
# Out:
# 80
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
print(f"{lat_lon_grid[0][0]}, {lat_lon_grid[0][1]}")
# Out:
# 48.024740672962935, 11.375352680629076

# %%
test_loc_lat = [map_center[0]-m_to_lat(10000), map_center[1]]
test_loc_lon = [map_center[0], map_center[1]-m_to_lon(10000, 48.19)]
print(map_center)
print(
print(test_loc_lat)
print(test_loc_lon)
# Out:
# 26686.61841257493
# 0.6666625702038126
# 0.13489906980135233
# [48.192091, 11.616458]
# [48.102144338370344, 11.616458]
# [48.192091, 11.481558930198647]

# %%
# Load the DataFrame from the JSON file
input_file_path = 'munich_doener_df.json'
doener_df = pd.read_json(input_file_path, lines=True)

munich= "48.137174, 11.577493"

munich_center = [float(string) for string in munich.split(', ')]
doener_map = folium.Map(location=munich_center, zoom_start=11)

# Add markers for each location
for place in doener_df.iterrows():
    # print(place[1]['lat'])
    folium.Marker(
        location=[place[1]['lat'], place[1]['lon']],
        popup=place[1]['name'],
        color='blue'
    ).add_to(doener_map)

for center in lat_lon_grid:
    # print(place[1]['lat'])
    folium.Marker(
        location=[center[0], center[1]],
        icon=folium.Icon(color='green',icon_color='#008000')
    ).add_to(doener_map)

doener_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
print(len(doener_df))
# Out:
# 304

# %%
print(doener_df)
# Out:
#                                          name  \
# 0    Cizz Bizz Grillhouse Döner Kebab Gauting
# 1                          Stern Döner Imbiss
# 2               CAN’S Döner Gauting Kebabhaus
# 3                           Mix kebaphaus No2
# 4                     Döner & Burger Brothers
# ..                                        ...
# 299                                  Curry 62
# 300                         Emmi's Kebap Haus
# 301                             Sultan Imbiss
# 302                           Harman Pizzeria
# 303                               Döner Pirat
#
#                                                address        lat        lon  \
# 0                      August-Hörmann-Platz 2, Gauting  48.066024  11.383611
# 1                            Bahnhofstraße 22, Gauting  48.068269  11.378402
# 2                            Bahnhofstraße 36, Gauting  48.070020  11.377190
# 3    Parking lot, Oskar-Von-Miller-Straße 1, Germering  48.131658  11.371644
# ...

# %%
for idx, place in doener_df.iterrows():
    print(place['place_id'])
# Out:
# ChIJVWd1XiDRnUcRyYHc4yNZDUM
# ChIJ64vDZc7QnUcR1_tBKzqfE0o
# ChIJi8Id8c3QnUcRIaOgnHhfIPQ
# ChIJfQsr7kbWnUcRyqz-_wWjuNU
# ChIJda7DRkLWnUcRP4x0rtMcbW4
# ChIJ8WeYVEPWnUcRnIMEYHMNfz8
# ChIJuWVy6Ll5nkcRIxom8bGe3_Q
# ChIJqRkpsUR5nkcRMD9LzHt5nEM
# ChIJuxOnr-d4nkcRKkxT9ehZjCk
# ChIJTcW5xAh5nkcRlJadGLVNz_o
# ChIJd2OTXst5nkcRSBNLeqY0Pdw
# ChIJG1VatrV4nkcRbPAnva4bjFE
# ChIJLcfGrt14nkcRaud5kg82GC0
# ChIJ4R6Ov9d4nkcRlpuAhdwSoDI
# ChIJTRlX3N14nkcRKi7x_QmKIIQ
# ChIJBzfnsrV4nkcRTkF_8xXaV-g
# ChIJI01aPel5nkcRmxAsf-hLjRI
# ChIJ--7TyNV4nkcRJZhmoO3TaOY
# ChIJ4wG9afJ7nkcRdw6hP4Zc6fE
# ChIJpxlDF3rXnUcRECGeNci4N2Y
# ChIJqZ--DRrXnUcRxilvZlU9Zok
# ChIJp4WKO_PXnUcRmkkeeVh8PAo
# ChIJ15L7u-DXnUcRpVb9neoBOSs
# ChIJE1Oczcl5nkcRag01MOkhvLo
# ChIJT6r7j-DXnUcRY9M6Wpbrxpc
# ChIJIT7OJa_XnUcRWTiZtqC1Vto
# ChIJgf9AH3R4nkcRfZVzrlSXqMQ
# ChIJO1-8b_zXnUcRntRFMHb0PfY
# ChIJI5AtbE16nkcR_r54lACdSsI
# ChIJZ1j9CQl7nkcRlw72uGsH5f4
# ChIJ_eIm3Jx7nkcR8Vct7ARAMwo
# ChIJPzF9hUt6nkcR2oRMeU-yDEI
# ChIJfcimmK57nkcRC_5KxoM92ho
# ...
